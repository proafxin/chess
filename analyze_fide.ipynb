# %%
from pandas import (
    read_csv,
    DataFrame,
    merge,
)
from numpy import (
    std,
    nan,
)

# %%
df = read_csv(
    'ratings_fide_november_2020.csv',
    low_memory=False,
    encoding='latin-1',
)

# %%
"""
Check 'descriptions.txt' for details on the fields
Field names do not exactly match descriptions on the ratings page in FIDE site.
"""
df.head()
# Out:
#      fideid                       name country sex title w_title o_title  \
# 0  10688862       A Abdel Maabod, Hoda     EGY   F   NaN     NaN     NaN
# 1  10224084  A B M Hasibuzzaman, Tapan     BAN   M   NaN     NaN     NaN
# 2  10245154      A B M Jobair, Hossain     BAN   M   NaN     NaN     NaN
# 3  10243054  A B M Mustakim, Chowdhury     BAN   M   NaN     NaN     NaN
# 4  25121731                 A C J John     IND   M   NaN     NaN     NaN
#
#   foa_title  rating  games     k  rapid_rating  rapid_games  rapid_k  \
# 0       NaN     NaN    NaN   NaN           NaN          NaN      NaN
# 1       NaN     NaN    NaN   NaN           NaN          NaN      NaN
# 2       NaN     NaN    NaN   NaN        1599.0          0.0     20.0
# 3       NaN     NaN    NaN   NaN           NaN          NaN      NaN
# 4       NaN  1063.0    0.0  40.0           NaN          NaN      NaN
#
#    blitz_rating  blitz_games  blitz_k  birthday flag
# 0           NaN          NaN      NaN    2009.0    w
# 1           NaN          NaN      NaN    1977.0  NaN
# 2           NaN          NaN      NaN    1998.0  NaN
# 3           NaN          NaN      NaN    2013.0  NaN
# 4           NaN          NaN      NaN    1987.0  NaN

# %%
df.shape
# Out:
# (983184, 19)

# %%
df['sex'].value_counts()
# Out:
# M    837331
# F    145853
# Name: sex, dtype: int64

# %%
"""
Drop players who have no rating
"""
df = df.dropna(
    subset=[
        'rating',
    ],
)
df.shape
# Out:
# (364307, 19)

# %%
df.head()
# Out:
#       fideid                      name country sex title w_title o_title  \
# 4   25121731                A C J John     IND   M   NaN     NaN     NaN
# 5   35077023            A Chakravarthy     IND   M   NaN     NaN     NaN
# 6   10207538          A E M, Doshtagir     BAN   M   NaN     NaN     NaN
# 10  10680810  A hamed Ashraf, Abdallah     EGY   M   NaN     NaN     NaN
# 11   5716365           A Hamid, Harman     MAS   M   NaN     NaN      NI
#
#    foa_title  rating  games     k  rapid_rating  rapid_games  rapid_k  \
# 4        NaN  1063.0    0.0  40.0           NaN          NaN      NaN
# 5        NaN  1151.0    0.0  40.0           NaN          NaN      NaN
# 6        NaN  1840.0    0.0  40.0        1836.0          0.0     20.0
# 10       NaN  1728.0    0.0  40.0           NaN          NaN      NaN
# 11       NaN  1325.0    0.0  40.0        1593.0          0.0     20.0
#
#     blitz_rating  blitz_games  blitz_k  birthday flag
# 4            NaN          NaN      NaN    1987.0  NaN
# 5            NaN          NaN      NaN    1986.0    i
# 6         1860.0          0.0     20.0    1974.0    i
# 10        1741.0          0.0     20.0    2001.0  NaN
# 11           NaN          NaN      NaN    1970.0    i

# %%
df['sex'].value_counts()
# Out:
# M    325429
# F     38878
# Name: sex, dtype: int64

# %%
"""
Drop players who are inactive
"""
df = df[df['flag'].isnull()]
df.shape
# Out:
# (175840, 19)

# %%
df.head()
# Out:
#       fideid                      name country sex title w_title o_title  \
# 4   25121731                A C J John     IND   M   NaN     NaN     NaN
# 10  10680810  A hamed Ashraf, Abdallah     EGY   M   NaN     NaN     NaN
# 17  10206612             A K M, Sourab     BAN   M   NaN     NaN     NaN
# 18   5045886             A K, Kalshyan     IND   M   NaN     NaN     NaN
# 29   5716373     A Rajah, Abdul Shukor     MAS   M   NaN     NaN     NaN
#
#    foa_title  rating  games     k  rapid_rating  rapid_games  rapid_k  \
# 4        NaN  1063.0    0.0  40.0           NaN          NaN      NaN
# 10       NaN  1728.0    0.0  40.0           NaN          NaN      NaN
# 17       NaN  1598.0    0.0  20.0           NaN          NaN      NaN
# 18       NaN  1777.0    0.0  20.0           NaN          NaN      NaN
# 29       NaN  1847.0    0.0  40.0        2015.0          0.0     20.0
#
#     blitz_rating  blitz_games  blitz_k  birthday flag
# 4            NaN          NaN      NaN    1987.0  NaN
# 10        1741.0          0.0     20.0    2001.0  NaN
# 17           NaN          NaN      NaN       NaN  NaN
# 18           NaN          NaN      NaN    1964.0  NaN
# 29        1873.0          0.0     20.0       NaN  NaN

# %%
df['sex'].value_counts()
# Out:
# M    175840
# Name: sex, dtype: int64

# %%
"""
Sort the rows by country
"""
df = df.sort_values(
    by=[
        'country',
    ],
)

# %%
df.head()
# Out:
#           fideid                    name country sex title w_title o_title  \
# 781825  11700580     Sarwari, Hamidullah     AFG   M   NaN     NaN     NaN
# 338981  11700718    Habibullah, Guldoost     AFG   M   NaN     NaN     NaN
# 580084  11701552       Mohtaat, Homayoun     AFG   M   NaN     NaN     NaN
# 811140  11701064  Shir Ahmad Wahab Zadah     AFG   M   NaN     NaN     NaN
# 965715  11702010      Yusuf, Abdul Majid     AFG   M   NaN     NaN     NaN
#
#        foa_title  rating  games     k  rapid_rating  rapid_games  rapid_k  \
# 781825       NaN  1863.0    0.0  20.0        1840.0          0.0     20.0
# 338981       NaN  1601.0    0.0  20.0           NaN          NaN      NaN
# 580084       AIM  1791.0    8.0  20.0        1680.0          0.0     20.0
# 811140       NaN  1292.0    0.0  40.0        1372.0          0.0     20.0
# 965715       NaN  1137.0    0.0  40.0           NaN          NaN      NaN
#
#         blitz_rating  blitz_games  blitz_k  birthday flag
# 781825        1829.0          0.0     20.0    1989.0  NaN
# 338981           NaN          NaN      NaN       NaN  NaN
# 580084        1796.0          0.0     20.0    1972.0  NaN
# 811140        1389.0          0.0     20.0    1976.0  NaN
# 965715           NaN          NaN      NaN    1958.0  NaN

# %%
"""
Take players who has at least one rated game
"""
df = df[df['games'] > 0]
df.shape
# Out:
# (15850, 19)

# %%
df.head()
# Out:
#           fideid               name country sex title w_title o_title  \
# 580084  11701552  Mohtaat, Homayoun     AFG   M   NaN     NaN     NaN
# 922717   4701313    Veleshnja, Zino     ALB   M   NaN     NaN     NaN
# 935875   4703529       Vogli, Erjon     ALB   M   NaN     NaN     NaN
# 66128    4700066      Ashiku, Franc     ALB   M    IM     NaN   SI,SI
# 918865   4701496    Vasili, Marinel     ALB   M   NaN     NaN     NaN
#
#        foa_title  rating  games     k  rapid_rating  rapid_games  rapid_k  \
# 580084       AIM  1791.0    8.0  20.0        1680.0          0.0     20.0
# 922717       NaN  2278.0    7.0  20.0        2104.0          0.0     20.0
# 935875       NaN  1557.0    5.0  40.0        1489.0          0.0     20.0
# 66128        NaN  2420.0    7.0  10.0        2378.0          0.0     20.0
# 918865       NaN  1616.0    3.0  40.0           NaN          NaN      NaN
#
#         blitz_rating  blitz_games  blitz_k  birthday flag
# 580084        1796.0          0.0     20.0    1972.0  NaN
# 922717        2058.0          0.0     20.0    2001.0  NaN
# 935875        1458.0          0.0     20.0    2003.0  NaN
# 66128         2306.0          0.0     20.0    1993.0  NaN
# 918865           NaN          NaN      NaN    2002.0  NaN

# %%
df['sex'].value_counts()
# Out:
# M    15850
# Name: sex, dtype: int64
